# %% [markdown]
# <a href="https://colab.research.google.com/github/wafamahmud/Dataset-all-project-copy/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
import matplotlib.pyplot as plt
x=[0, 5, 10, 15, 20, 25, 30]
y1=[10, 15, 20, 20, 30, 15, 0]
y2=[10, 12, 15, 12, 20, 10, 0]
plt.plot(x, y1, linestyle='dashed', marker='D')
plt.plot(x, y2, linestyle='dashed', marker='D')
plt.title('Velocity-Time Graph')
plt.xlabel('Velocity m/s')
plt.ylabel('Time (s)')
plt.xlim(5, 25)
plt.ylim(5, 25)
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-2500220367.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
